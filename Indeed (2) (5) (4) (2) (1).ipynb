# %%
import sys
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
#City="Tampa"
#State="FL"
#URL="https://www.indeed.com/jobs?q=quality%20manager&l=Tampa%2C%20FL&from=searchOnHP&vjk=9fc7b107970872a0"
    

def PageScan(page_num):
    URL="https://www.indeed.com/jobs?q=quality+manager&l=Tampa%2C+FL&start="+str(page_num)
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")
    res=soup.find_all("a",{"class":"jcs-JobTitle css-jspxzf eu4oa1w0"})
    #print(res)
    ScanOut=[]
    for link in res: 
        ScanOut.append(link.get('href'))
    return ScanOut


def GetDesc(URL):
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")
    
    try:
        Company=soup.find_all(class_="icl-u-lg-mr--sm icl-u-xs-mr--xs")[1].text
    except: 
        Company="NA"
        
    try:
        Rating=soup.select('div meta')[0].attrs['content']
    except: 
        Rating="NA"
    
    #Position=soup.find({"class":"icl-u-xs-mb--xs icl-u-xs-mt--none jobsearch-JobInfoHeader-title"})
    try:
        Title=soup.find_all('h1')[0].get_text() #100%
    except: 
        Title="NA"
        
    try:
        JobDescription=soup.find_all(class_="jobsearch-jobDescriptionText")[0].p.text #80%
    except: 
        JobDescription="NA"        
        
    try: 
        Salary=soup.find(class_="jobsearch-JobDescriptionSection is-highlight-enforced").div.span.text
    except: 
        Salary="NA"
        
    #Responsibilities=soup.find(id="jobDescriptionText").find_all("ul")[0].get_text()
    
    #Qualifications=soup.find_all(class_="icl-u-xs-my--none")[0].text
    #return(Title,Salary, Company,Rating, JobDescription,Qualifications, Responsibilities)
    return(Title,Company, Salary,JobDescription)


URL_list=[]
page_no=0
for i in range (1,2):
    
    URL_list.append(PageScan(page_no))
    page_no=page_no+1
URL_list=(np.array(URL_list))

#print(URL_list.shape[0])
#print(URL_list)
#print('skip')
URL_list=np.resize(URL_list,(1,URL_list.shape[0]*URL_list.shape[1]))
#print(URL_list)
    
outs=pd.DataFrame(columns=['Title', 'Company' ,'Salary' , 'JobDescription'])
#row=0
for i in URL_list[0]:
    print(i)
    print('check')
    try:
        a=GetDesc(str("http://indeed.com"+i))
        outs.loc[len(outs)]=a
        #for item in a: 
            #print(item)
            
        #row=row+1
        print(a)
    except:
        pass
print(outs)
outs.to_csv('indeed.csv')
# Out:
# /pagead/clk?mo=r&ad=-6NYlbfkN0CjvTxxWeXWO2vcjag7rSephe-bUEeLRfD--m68jvPeTeFRjeYD9Ek0wfrwBUHGF0z1q_I4WgGc_-DHcrSxLELMrLOGi4buOuNo6FpNjxObkUsQcTpzsWIQRyV-N0CVQ3NEGMPEQVYS7GDKgwrXolU3PuApwLne_VDBxlC72s4SPwA04E3htmVcAlveu6uaImRh9oDwWIE20osy1bW9JzHb9gbGt1FZuWNt9BkavWARJxQvZS9I_blWJrvzQ-G6WMIFNrAqrn-qxjvNuxvQdIucRE01pfuJp7blSe6SZg5aH5x-sngmTXDRhd8_inOvX2-FIeIBnHxebxCJg4SPyWRFeSznnzlYRu3pizxQTkKY3kqQp1WP63XiaXct38Clfw0F6oMokIXOBdiVGnoCrnBZGkSnenA5C0Yv8WhGEEWOf6aMLw8yjjCxRKMr5so_sOQuBjLzyhmIbtDq_umROXEivGTEn6m6IYzcN7aHJaI8Pw==&xkcb=SoDu-_M3cvhHaswBqp0LbzkdCdPP&p=0&fvj=0&vjs=3
# check
# ('Quality Manager', 'Compulink Cable Assemblies of Florida, INC', 'NA', ' ')
# check
# ('Quality Manager - Metal Finishing - Bloomingdale', 'Michael Page', '$90,000 - $110,000 a year', "  MPI does not discriminate on the basis of race, color, religion, sex, sexual orientation, gender identity or expression, national origin, age, disability, veteran status, marital status, or based on an individual's status in any group or class protected by applicable federal, state or local law. MPI encourages applications from minorities, women, the disabled, protected veterans and all other qualified applicants.")
# /company/Benchmark-International/jobs/Merger-Acquisition-Quality-Manager-f27280c2b38fd3ea?fccid=f714145a88727193&vjs=3
# check
# ('Merger & Acquisition Quality Manager', 'Benchmark International', 'Up to $100,000 a year', 'The M&A Quality Manager will ensure uniformity in Transaction Support activities, across Benchmark’s US offices and teams, consistent with established business processes. Transaction Support includes business writers and financial analysts that create financial reports, analyze results, write detailed confidential information memorandums, and prepare our clients for the sale of their business (mergers and acquisitions). Reporting to Benchmark’s Head of Operations, the Quality Manager is responsible for providing Transaction Support oversight across the US offices, including the development of relevant instructional guides, collaborating with management to identify training needs, assessing process conformance, reviewing teams’ work-products prior to publishing, providing continuous training for relevant employee groups, identifying and sharing best practices, and maintaining documents in a controlled manner.')
# /rc/clk?jk=a4113ed2e3712062&fccid=212b69108ea3ebdd&vjs=3
# check
# ('Quality Assurance Manager 1', 'AMETEK, Inc.', 'NA', 'Your Impact:')
# /company/Dewolff,-Boberg-&-Associates/jobs/Continuous-Improvement-Manager-e91a8f3c7ea7eed7?fccid=6dde0fffe3bf538f&vjs=3
# check
# ('Continuous Improvement Manager', 'Dewolff, Boberg & Associates', '$185,000 - $190,000 a year', 'Job Summary')
# /rc/clk?jk=7ee8a336f5bf61b3&fccid=9e215d88a6b33622&vjs=3
# check
# ('Quality Assurance Program Manager', 'Deloitte', 'NA', 'NA')
# /rc/clk?jk=4b9fcb4985484345&fccid=372688670c2370a2&vjs=3
# check
# ('Division Director of Quality', 'HCA Healthcare', 'NA', 'Description ')
# /rc/clk?jk=cf1cfdd7793b7b48&fccid=27b567b3ba2dd1ca&vjs=3
# check
# ('Director, Quality', 'General Dynamics Ordnance & Tactical Systems', 'NA', ' Directs the overall management of the Quality Department’s function through subordinate managers. Is responsible for productivity, expense levels and asset management. Oversees the operational management and problem solving, budgets, schedules and performance standards while ensuring conformance to sub-contractual requirements by performing the following duties.')
# /rc/clk?jk=70ebd5c621973ffb&fccid=fe2257615884b620&vjs=3
# check
# ('Supervisor, Quality Assurance', 'Bausch + Lomb', 'NA', 'NA')
# /company/VelocityEHS/jobs/Senior-Manager-494ce82c99df0712?fccid=400211f86bfa5b56&vjs=3
# check
# ('Senior Manager, Quality Assurance', 'VelocityEHS', 'NA', 'THE OPPORTUNITY: *Open to remote candidates in the United States and Canada*At VelocityEHS we are seeking a Senior Manager, Quality Assurance to support the growth of our Development Team. We are looking for passionate and enthusiastic people who love solving complex business problems. You will be managing a growing test team of Quality Analysts and Test Engineers in an agile software development environment. This position will be working closely with architects, developers, testers, and business analysts as well as product managers and the DevOps team.As Senior Manager, Quality Assurance at VelocityEHS, you will have the ability to showcase your passion for quality combined with your leadership skills in order to strategically align the team to business objectives. You will mentor the individual members of your team through career development, identifying areas for growth and a constant reflection on improvement. Interfacing with global teams, you will be challenged with identifying technical solutions for automating testing of our SaaS applications. This is a new opportunity with a growing team. Test automation is an exciting endeavor,and you will be helping grow and mentor the team as the company grows!PRIMARY DUTIES AND RESPONSIBILITIES: ')
# /rc/clk?jk=5315ae017594da73&fccid=2bbba1c4c8e1286d&vjs=3
# check
# ('Director, System Quality - Performance Improvement', 'Tampa General Hospital', 'NA', "Under the general supervision of the Chief Quality Officer, directs the organization-wide quality improvement effort, to include development and maintenance of the institution's performance improvement plan, coordination of performance improvement activities in all system settings to achieve our strategic goals. This is done by coordinating the activities and priorities of patient safety, infection prevention, performance improvement to evaluate and improve outcomes across the continuum of care. Interviews, hires, schedules, assigns work to, and evaluates the work performance of employees supervised. Responsible for performing job duties in accordance with the mission, vision, and values of Tampa General Hospital.")
# /rc/clk?jk=b2a30039f70b2c1b&fccid=28ce112590363228&vjs=3
# check
# ('Manager, Quality & Patient Safety', 'H. Lee Moffitt Cancer Center', 'NA', 'MANAGER, QUALITY & PATIENT SAFETY')
# /company/The-Crisis-Center/jobs/Ems-Performance-Quality-Improvement-Training-Manager-aafdbd98ccadba06?fccid=91d0f447b3c2fead&vjs=3
# check
# ('EMS Performance Quality Improvement & Training Manager', 'The Crisis Center', 'NA', 'Position SummaryThe Crisis Center of Tampa Bay (Crisis Center) brings help, hope and healing to people facing serious life challenges or trauma resulting from sexual assault or abuse, domestic violence, financial distress, substance abuse, medical emergency, suicidal thoughts, emotional or situational problems. This position is responsible for working in conjunction with the Senior Director of TransCare and Organizational Development team to maintain the integrity of the organization’s Performance Quality Improvement (PQI), Quality Assurance (QA), Compliance and Contract measures in accordance with all federal and state laws, administrative code, operating procedures, other regulations and accreditation standards, while providing a high level of training and development to TransCare, our EMS division.Strategic/Transformational Duties and Responsibilities')
# /rc/clk?jk=7f82413de496d99b&fccid=c1331157ea59b44d&vjs=3
# check
# ('Quality Assurance Manager', 'Gale Healthcare Solutions', '$55,000 a year', 'NA')
#                                                 Title  \
# 0                                     Quality Manager
# 1                                          QC Manager
# 2    Quality Manager - Metal Finishing - Bloomingdale
# 3                Merger & Acquisition Quality Manager
# 4                         Quality Assurance Manager 1
# 5                      Continuous Improvement Manager
# 6                   Quality Assurance Program Manager
# 7                        Division Director of Quality
# 8                                   Director, Quality
# 9                       Supervisor, Quality Assurance
# 10                  Senior Manager, Quality Assurance
# 11  Director, System Quality - Performance Improve...
# 12                  Manager, Quality & Patient Safety
# 13  EMS Performance Quality Improvement & Training...
# 14                          Quality Assurance Manager
#
#                                          Company                      Salary  \
# 0     Compulink Cable Assemblies of Florida, INC                          NA
# 1                        Supplement Manufacturer    $65,000 - $80,000 a year
# 2                                   Michael Page   $90,000 - $110,000 a year
# 3                        Benchmark International       Up to $100,000 a year
# 4                                   AMETEK, Inc.                          NA
# 5                   Dewolff, Boberg & Associates  $185,000 - $190,000 a year
# 6                                       Deloitte                          NA
# 7                                 HCA Healthcare                          NA
# 8   General Dynamics Ordnance & Tactical Systems                          NA
# 9                                  Bausch + Lomb                          NA
# 10                                   VelocityEHS                          NA
# 11                        Tampa General Hospital                          NA
# 12                  H. Lee Moffitt Cancer Center                          NA
# 13                             The Crisis Center                          NA
# 14                     Gale Healthcare Solutions              $55,000 a year
#
#                                        JobDescription
# 0
# 1                                                   *
# 2     MPI does not discriminate on the basis of ra...
# 3   The M&A Quality Manager will ensure uniformity...
# 4                                        Your Impact:
# 5                                         Job Summary
# 6                                                  NA
# 7                                        Description
# 8    Directs the overall management of the Quality...
# 9                                                  NA
# 10  THE OPPORTUNITY: *Open to remote candidates in...
# 11  Under the general supervision of the Chief Qua...
# 12                  MANAGER, QUALITY & PATIENT SAFETY
# 13  Position SummaryThe Crisis Center of Tampa Bay...
# 14                                                 NA

# %%
import sys

#!{sys.executable} -m pip install lxml
from lxml import etree
#!{sys.executable} -m pip install beautifulsoup4
import requests
from bs4 import BeautifulSoup

## EXTRACT Pos NAME

URL = "https://www.indeed.com/viewjob?jk=9fc7b107970872a0&q=quality+manager&l=Tampa,+FL&from=web&advn=5762298694980534&adid=109133283&ad=-6NYlbfkN0BEDyJBSx9oqefqCav6hOw-T5ckpQBd37exZt4GFrGfjPPKHQItgk4TGXp5PwKHXTwlbcZwGXeZHj8LADRwasG0pVl15vyGG_kS7aY2_WivoD59RhuzolgQmCnIyP5UvcrRsuIFoincq2BAY-GJEu4z-r1LxLxgoPEc0lrrA2T90oIKunzrqJc4IYOf2_V2iBA81T9zCd1Hp0Z9Volj18pDUC4WbLnrCcL8ORpyrqSAe0uR4PxYikjInPRr8ozEqQoPC_Xs1Z-9cfTaexSAcoGVTTNIeiueptVJRb-BiL-2ess6nbHfw6ZZN9L7H7ILOermBSq0tm0Vi8ExiMdHfgVPbBL4hqvmyoU5rFx48nDCk1sqH5pAKYmb8gvTLabEx6Y%3D&pub=4a1b367933fd867b19b072952f68dceb&vjs=3"
soup = BeautifulSoup(page.content, "html.parser")
## Method 1
a=soup.find_all('h1')[0].get_text()

# Method 2
b=soup.select("div div h1")[0].get_text()

#Method 3
c=soup.find_all(class_="icl-u-xs-mb--xs icl-u-xs-mt--none jobsearch-JobInfoHeader-title")[0].get_text()

#Method 4

print(a,c)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_61/1063644974.py in <module>
#      15
#      16 # Method 2
# ---> 17 b=soup.select("div div h1")[0].get_text()
#      18
#      19 #Method 3
#
# IndexError: list index out of range

# %%
import sys

#!{sys.executable} -m pip install lxml
from lxml import etree
#!{sys.executable} -m pip install beautifulsoup4
import requests
from bs4 import BeautifulSoup

URL ="https://www.indeed.com/viewjob?cmp=Benchmark-International&t=Merger+Acquisition+Quality+Manager&jk=f27280c2b38fd3ea&q=Merger+%26+Acquisition+Quality+Manager&vjs=3"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")

#a=(soup.select("div nav div"))
a=soup.find_all('p')
#for i in a:
   # #print('step')
   # print(i.get_text())
a=soup.find_all(class_="jobsearch-jobDescriptionText")[0].p.text

print(a)

#a=soup.select('div div div span')
#a=soup.find_all(class_="icl-u-xs-mr--xs")[0].get_text()
#print(a)
# Out:
# The M&A Quality Manager will ensure uniformity in Transaction Support activities, across Benchmark’s US offices and teams, consistent with established business processes. Transaction Support includes business writers and financial analysts that create financial reports, analyze results, write detailed confidential information memorandums, and prepare our clients for the sale of their business (mergers and acquisitions). Reporting to Benchmark’s Head of Operations, the Quality Manager is responsible for providing Transaction Support oversight across the US offices, including the development of relevant instructional guides, collaborating with management to identify training needs, assessing process conformance, reviewing teams’ work-products prior to publishing, providing continuous training for relevant employee groups, identifying and sharing best practices, and maintaining documents in a controlled manner.
