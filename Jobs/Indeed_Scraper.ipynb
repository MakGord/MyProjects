# %%
import sys
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
#City="Tampa"
#State="FL"
#URL="https://www.indeed.com/jobs?q=quality%20manager&l=Tampa%2C%20FL&from=searchOnHP&vjk=9fc7b107970872a0"


#City%2C+State
#State
#Country
#Remote


def PageScan(page_num):
    Title="quality%20manager"
    #Minimum_Salary="+50,000"
    Location="Tampa%2C%20+FL&radius=100"
    #Location=""
    #Radius=100
    URL="https://www.indeed.com/jobs?q="+Title+"&l="+Location+"&start="+str(page_num*10)
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")
    res=soup.find_all("a",{"class":"jcs-JobTitle css-jspxzf eu4oa1w0"})
    ScanOut=[]
    for link in res: 
        ScanOut.append(link.get('href'))
    return ScanOut


def GetDesc(URL):
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")
    
    try:
        Company=soup.find_all(class_="icl-u-lg-mr--sm icl-u-xs-mr--xs")[1].text
    except: 
        Company="NA"
        
    try:
        Rating=soup.select('div meta')[0].attrs['content']
    except: 
        Rating="NA"
    
    #Position=soup.find({"class":"icl-u-xs-mb--xs icl-u-xs-mt--none jobsearch-JobInfoHeader-title"})
    try:
        Title=soup.find_all('h1')[0].get_text() #100%
    except: 
        Title="NA"
        
    try:
        JobDescription=soup.find_all(class_="jobsearch-jobDescriptionText")[0].p.text 
    except: 
        JobDescription="NA"        
        
    try: 
        Salary=soup.find(class_="jobsearch-JobDescriptionSection is-highlight-enforced").div.span.text
    except: 
        Salary="NA"
    
    try:
        Responsibilities=soup.find(id="jobDescriptionText").find_all("ul")[0].get_text()
    except: 
        Responsibilities = "NA"
        
    try: 
        Qualifications=soup.find_all(class_="icl-u-xs-my--none")[0].text
    except: 
        Qualifications="NA"
        
    try:
        Full_Description=soup.find_all(class_="jobsearch-jobDescriptionText")[0].text
    except: 
        Full_Description="NA"

    return(Title,Company,Rating, Salary,JobDescription,Responsibilities,Qualifications,URL,Full_Description)


URL_list=[]
for i in range (0,3):
    
    URL_list.append(PageScan(i))

URL_list=(np.array(URL_list))

URL_list=np.resize(URL_list,(1,URL_list.shape[0]*URL_list.shape[1]))

outs=pd.DataFrame(columns=['Title', 'Company','Rating' ,'Salary' , 'JobDescription','Responsibilities','Qualifications','link','Full_Description'])
#row=0
for i in URL_list[0]:
    #print(i)
    #print('check')
    try:
        a=GetDesc(str("http://indeed.com"+i))
        outs.loc[len(outs)]=a
        #for item in a: 
            #print(item)
            
        #row=row+1
        #print(a)
    except:
        pass
print(outs)
outs.to_csv('indeed.csv')
# Out:
#                                                 Title  \
# 0                                     Manager Quality
# 1                Merger & Acquisition Quality Manager
# 2                                     Quality Manager
# 3                                   Director, Quality
# 4                   Senior Manager, Quality Assurance
# 5   EMS Performance Quality Improvement & Training...
# 6                         Quality Assurance Manager 1
# 7                      Continuous Improvement Manager
# 8    Global Assurance Quality and Risk Senior Manager
# 9                   Quality Assurance Program Manager
# 10  ECDO Quality Review and Challenge Senior Manag...
# 11                  Manager, Quality & Patient Safety
# 12                     Continuous Improvement Manager
# 13                                    Quality Manager
# 14  ICG Data Quality Controls and Monitoring Group...
# 15                  Quality Assurance Manager, Senior
# 16                     Continuous Improvement Manager
# 17  Quality Assurance Engineering Senior Manager -...
# 18                     Continuous Improvement Manager
# 19            SDET Quality Assurance Manager (DevOps)
# 20     Deloitte Technology Quality Managment Director
# 21  Director, System Quality - Performance Improve...
# 22                 Assistant Director of Systems & QC
# 23       ICG KYC Quality – Team Lead - VP / Tampa, FL
# 24     Director - Quality and Performance Improvement
# 25          Quality Assurance Team Leader, ON, Bakery
# 26                   Software Process Quality Manager
# 27                        Quality Improvement Manager
# 28                             Quality System Manager
# 29  Lead Quality Program Strategist - CAHPS and SD...
# 30                Regional Manager, Quality Assurance
# 31        Quality Produce Manager - Kroger- Groveland
# 32                           Quality Assurance Leader
# 33  Program Quality Engineering Manager - Orlando, FL
# 34                        Housekeeping Quality Leader
# 35                          Data Quality Lead Analyst
# 36                    Manager, Implementation Quality
# 37  Software Quality Engineering (SSQE) Team Lead ...
# 38        Transformation PM Process Quality Lead- C13
# 39           Sr. Design Build Project Quality Manager
# 40          Practice Lead I, Quality Engineering (US)
# 41                                Director of Quality
# 42                                    Quality Manager
# 43  Manager Quality Improvement, Patient Safety an...
# 44                    Regulatory & Compliance Manager
#
#                                          Company Rating  \
# 0                                         CIRCOR    3.2
# 1                        Benchmark International      4
# 2                                       WestRock    3.1
# 3   General Dynamics Ordnance & Tactical Systems    3.3
# 4                                    VelocityEHS    3.9
# 5                              The Crisis Center      3
# 6                                   AMETEK, Inc.    3.4
# 7                                   Plasma-Therm     NA
# 8                                       Deloitte      4
# 9                                       Deloitte      4
# 10                                          Citi    3.9
# 11                  H. Lee Moffitt Cancer Center      4
# 12                             Plasma-Therm, LLC      3
# 13    Compulink Cable Assemblies of Florida, INC     NA
# 14                                          Citi    3.9
# 15                           Booz Allen Hamilton    3.9
# 16                                 Paragon Water    2.6
# 17                   LOCKHEED MARTIN CORPORATION      4
# 18                         Paragon Water Systems    2.3
# 19                       Raymond James Financial    3.8
# 20                                      Deloitte      4
# 21                        Tampa General Hospital      4
# 22                   University of South Florida    4.2
# 23                                          Citi    3.9
# 24                           Park Royal Hospital    2.4
# 25                                        Publix      4
# 26                                          KPMG    3.9
# 27           Devereux Advanced Behavioral Health      3
# 28                           Abbott Laboratories    3.9
# 29                           Centene Corporation    3.2
# 30                                         SOFIE     NA
# 31                              Kroger Logistics    3.4
# 32                    Southeastern Freight Lines    3.9
# 33                   LOCKHEED MARTIN CORPORATION      4
# 34                   Marriott International, Inc    4.1
# 35                                          Citi    3.9
# 36                                          PSCU    3.2
# 37                   LOCKHEED MARTIN CORPORATION      4
# 38                                          Citi    3.9
# 39                              HNTB Corporation    3.6
# 40                                       TD Bank    3.8
# 41                                 Fanatics Inc.    3.6
# 42                                          CTDI    3.1
# 43                                       BayCare    3.9
# 44                         Carmine's Bakery, LLC    3.7
#
#                        Salary  \
# 0                          NA
# 1       Up to $100,000 a year
# 2                          NA
# 3                          NA
# 4                          NA
# 5                          NA
# 6                          NA
# 7                          NA
# 8                          NA
# 9                          NA
# 10                         NA
# 11                         NA
# 12                         NA
# 13                         NA
# 14                         NA
# 15                         NA
# 16                         NA
# 17                         NA
# 18                         NA
# 19                         NA
# 20                         NA
# 21                         NA
# 22             $60,000 a year
# 23                         NA
# 24                         NA
# 25   $46,384 - $63,960 a year
# 26                         NA
# 27        From $59,000 a year
# 28                         NA
# 29                         NA
# 30                         NA
# 31                         NA
# 32                         NA
# 33                         NA
# 34                         NA
# 35                         NA
# 36                         NA
# 37                         NA
# 38                         NA
# 39                         NA
# 40                         NA
# 41                         NA
# 42                         NA
# 43                         NA
# 44  $90,000 - $120,000 a year
#
#                                        JobDescription  \
# 0                                     JOB DESCRIPTION
# 1   The M&A Quality Manager will ensure uniformity...
# 2                                                  NA
# 3    Directs the overall management of the Quality...
# 4   THE OPPORTUNITY: *Open to remote candidates in...
# 5   Position SummaryThe Crisis Center of Tampa Bay...
# 6                                        Your Impact:
# 7                                            SUMMARY:
# 8                                     Work you'll do:
# 9                                                  NA
# 10  The Chief Administrative Office Quality Review...
# 11                  MANAGER, QUALITY & PATIENT SAFETY
# 12                                           SUMMARY:
# 13
# 14  The ICG Data Quality Controls and Monitoring G...
# 15                                     The Challenge:
# 16  Specific Job Function: Leads and assists in se...
# 17  COVID-19 continues to significantly impact our...
# 18
# 19
# 20                                    Work you'll do:
# 21  Under the general supervision of the Chief Qua...
# 22       Dept Number/Name: 0-3730-000 / Financial Aid
# 23  The role will be part of the ICG KYC Ops. Qual...
# 24
# 25  In Quality Assurance (QA), Team Leaders serve ...
# 26  Known for being a great place to work and buil...
# 27                                                 NA
# 28  Abbott is a global healthcare leader that help...
# 29                                                 NA
# 30  Title | Regional Manager, Quality AssuranceLoc...
# 31  Company Name: Kroger Logistics Position Type: ...
# 32                                                 NA
# 33  COVID-19 continues to significantly impact our...
# 34
# 35  The Data Quality Lead Analyst is a strategic p...
# 36  For people drawn to serving others through the...
# 37  COVID-19 continues to significantly impact our...
# 38  Within the Chief Administrative Office (CAO), ...
# 39                             What We're Looking For
# 40                                     TD Description
# 41                                                 NA
# 42  CTDI is a large scale logistics repair and eng...
# 43   BayCare is currently in search of our newest ...
# 44
#
#                                      Responsibilities  \
# 0   \n Manage employees’ daily activities to ensur...
# 1   \nProvide oversight and ensure uniformity in T...
# 2                                                  NA
# 3   \nOversee the evaluation of highly complex inv...
# 4   \nGuide team through execution of Agile Proces...
# 5   \nThis position supports the mission of the Cr...
# 6   \nEnsure compliance with applicable government...
# 7   \nDevelop and implement methods and techniques...
# 8   \nContributing to the development of the Quali...
# 9   \n Planning and executing engagements to meet ...
# 10  \n Facilitate implementation and execution of ...
# 11  \nThis position has the 24-hour responsibility...
# 12  \nDevelop and implement methods and techniques...
# 13  \nDocumentation control and quality records in...
# 14  \n Develops strategies and guidelines for the ...
# 15  \n Experience with creating test management pl...
# 16  \nLead and facilitate the development and mana...
# 17                                                 NA
# 18  \n Lead and facilitate the development and man...
# 19  \nUnderstand and evaluate DevOps trends relate...
# 20  \nEstablish processes and governance to ensure...
# 21                                                 NA
# 22  \nSupervise Federal Grants Team Manager to ens...
# 23  \n Determine the strategy and process for all ...
# 24  \n • Three or more years’ experience in a Qual...
# 25  \nHACCP Plan development, monitoring and data ...
# 26  \n Support the Associate Director/Director of ...
# 27  \n A unique opportunity where the work you per...
# 28  \n Provide expertise and guidance in interpret...
# 29  \n Identifies trends within quality data utili...
# 30  \nEnsure compliance to all applicable standard...
# 31  \n Provide leadership to the site in areas of ...
# 32  \nTrain and develop new Freight Handlers in de...
# 33                                                 NA
# 34                                                 NA
# 35  \n Develops standards, procedures, guidelines ...
# 36  \nImplement and govern Implementations quality...
# 37                                                 NA
# 38  \n Excellent understanding of the PM Procedure...
# 39  \nIn collaboration with the Design Project Man...
# 40                                                 NA
# 41  \n\n Own, develop, implement, monitor quality ...
# 42  \nDevelop, execute, and analyze quality-report...
# 43  \nDisseminates and analyzes performance data i...
# 44  \n\n\n\n\n        Description \n        \nThe ...
#
#                             Qualifications  \
# 0                                       NA
# 1   Project management: 1 year (Preferred)
# 2                                       NA
# 3                                       NA
# 4                                       NA
# 5                                       NA
# 6                                       NA
# 7                                       NA
# 8                                       NA
# 9                                       NA
# 10                                      NA
# 11                                      NA
# 12                                      NA
# 13                                      NA
# 14                                      NA
# 15                                      NA
# 16                                      NA
# 17                                      NA
# 18                                      NA
# 19                                      NA
# 20                                      NA
# 21                                      NA
# 22                                      NA
# 23                                      NA
# 24                                      NA
# 25                                      NA
# 26                                      NA
# 27                                      NA
# 28                                      NA
# 29                                      NA
# 30                                      NA
# 31                                      NA
# 32                                      NA
# 33                                      NA
# 34                                      NA
# 35                                      NA
# 36                                      NA
# 37                                      NA
# 38                                      NA
# 39                                      NA
# 40                                      NA
# 41                                      NA
# 42                                      NA
# 43                                      NA
# 44                                      NA
#
#                                                  link  \
# 0   http://indeed.com/rc/clk?jk=d43595e4e6a9dfbc&f...
# 1   http://indeed.com/company/Benchmark-Internatio...
# 2   http://indeed.com/rc/clk?jk=31a6bd67c2c010c3&f...
# 3   http://indeed.com/rc/clk?jk=cf1cfdd7793b7b48&f...
# 4   http://indeed.com/company/VelocityEHS/jobs/Sen...
# 5   http://indeed.com/company/The-Crisis-Center/jo...
# 6   http://indeed.com/rc/clk?jk=a4113ed2e3712062&f...
# 7   http://indeed.com/rc/clk?jk=096bbc6d7f66b8b6&f...
# 8   http://indeed.com/rc/clk?jk=354b15715207d5ff&f...
# 9   http://indeed.com/rc/clk?jk=7ee8a336f5bf61b3&f...
# 10  http://indeed.com/rc/clk?jk=95eea14aa5a61711&f...
# 11  http://indeed.com/rc/clk?jk=b2a30039f70b2c1b&f...
# 12  http://indeed.com/rc/clk?jk=20328aeb80b6bdc1&f...
# 13  http://indeed.com/rc/clk?jk=547601f3b0e3d187&f...
# 14  http://indeed.com/rc/clk?jk=d13fa97530a07a4a&f...
# 15  http://indeed.com/rc/clk?jk=45631eede5e91981&f...
# 16  http://indeed.com/rc/clk?jk=9b2411f031e3adbc&f...
# 17  http://indeed.com/rc/clk?jk=48084eb39dbee590&f...
# 18  http://indeed.com/rc/clk?jk=b2c99760e0648c79&f...
# 19  http://indeed.com/rc/clk?jk=03b83dd0fb8bd186&f...
# 20  http://indeed.com/rc/clk?jk=83585a6b8a2e1f1c&f...
# 21  http://indeed.com/rc/clk?jk=5315ae017594da73&f...
# 22  http://indeed.com/rc/clk?jk=cdeb9e38cdcc733c&f...
# 23  http://indeed.com/rc/clk?jk=498da7293c27c058&f...
# 24  http://indeed.com/rc/clk?jk=11eb050e49db82f5&f...
# 25  http://indeed.com/rc/clk?jk=b39b8341b009fe48&f...
# 26  http://indeed.com/rc/clk?jk=bfe3143bb13fb215&f...
# 27  http://indeed.com/rc/clk?jk=26da4d4818f6497c&f...
# 28  http://indeed.com/rc/clk?jk=e2f8034aafe7a7ee&f...
# 29  http://indeed.com/rc/clk?jk=a78a1ed8fe43155d&f...
# 30  http://indeed.com/company/Sofie/jobs/Regional-...
# 31  http://indeed.com/rc/clk?jk=c8feabcc2a49424d&f...
# 32  http://indeed.com/rc/clk?jk=c79261b1e9100213&f...
# 33  http://indeed.com/rc/clk?jk=131e5253daf86e1b&f...
# 34  http://indeed.com/rc/clk?jk=ab509f4d508a7172&f...
# 35  http://indeed.com/rc/clk?jk=e6a51e2111307f82&f...
# 36  http://indeed.com/rc/clk?jk=bfb7837f754e8d59&f...
# 37  http://indeed.com/rc/clk?jk=67e4520f64544fb1&f...
# 38  http://indeed.com/rc/clk?jk=d5f2f6639c7877e2&f...
# 39  http://indeed.com/rc/clk?jk=9b0b4cd7acccd438&f...
# 40  http://indeed.com/rc/clk?jk=bb6ea8332769bf96&f...
# 41  http://indeed.com/rc/clk?jk=015d4d36663bd107&f...
# 42  http://indeed.com/rc/clk?jk=2b688b744a8419e7&f...
# 43  http://indeed.com/rc/clk?jk=49958d06df8ab78a&f...
# 44  http://indeed.com/rc/clk?jk=54551ced25c314d7&f...
#
#                                      Full_Description
# 0   \n\nJOB DESCRIPTION\n\n\nQuality Manager\n ORG...
# 1   The M&A Quality Manager will ensure uniformity...
# 2   Job Summary: The Quality Manager ensures that ...
# 3   \n Overview: \n  Directs the overall managemen...
# 4   THE OPPORTUNITY: *Open to remote candidates in...
# 5   Position SummaryThe Crisis Center of Tampa Bay...
# 6   \nYour Impact:\nAs a Quality Assurance Manager...
# 7   \nSUMMARY:\n The Continuous Improvement (CI) M...
# 8   \n Do you thrive on developing creative and in...
# 9   \n Unanticipated risks have great consequences...
# 10  \nThe Chief Administrative Office Quality Revi...
# 11  \nMANAGER, QUALITY & PATIENT SAFETY\nJOB SUMMA...
# 12  \nSUMMARY:\n The Continuous Improvement (CI) M...
# 13  \n\nSummary: Ensure quality system is maintain...
# 14  \nThe ICG Data Quality Controls and Monitoring...
# 15  \nThe Challenge:\n Are you an expert in digita...
# 16  \nSpecific Job Function: Leads and assists in ...
# 17  COVID-19 continues to significantly impact our...
# 18  \n\nSpecific Job Function: Leads and assists i...
# 19  \n\n\nAs a leader and technologist, the manage...
# 20  \n Do you thrive on developing creative and in...
# 21  \n\nDirector, System Quality - Performance Imp...
# 22  \n\nDept Number/Name: 0-3730-000 / Financial A...
# 23  \nThe role will be part of the ICG KYC Ops. Qu...
# 24  \n\nThe Director of Quality and Performance Im...
# 25  \n\nIn Quality Assurance (QA), Team Leaders se...
# 26  \nKnown for being a great place to work and bu...
# 27  \n Description: \n \n ** This position's salar...
# 28  \nAbbott is a global healthcare leader that he...
# 29  \nPosition Purpose:\n\n Identifies trends with...
# 30  Title | Regional Manager, Quality AssuranceLoc...
# 31  \nCompany Name: Kroger Logistics Position Type...
# 32  \n\n  Are you ready to join a best in class LT...
# 33  COVID-19 continues to significantly impact our...
# 34  \n\nPosting Date Jul 06, 2022\n  \nJob Number ...
# 35  \nThe Data Quality Lead Analyst is a strategic...
# 36  \nJoin the people helping people. \nFor people...
# 37  COVID-19 continues to significantly impact our...
# 38  \nWithin the Chief Administrative Office (CAO)...
# 39  \nWhat We're Looking For\nThe time is right to...
# 40  \n\n\n\nTD Description\n\nAbout TD Bank, Ameri...
# 41  \n\n\nCompany Overview\n\n\n\n\n    Fanatics i...
# 42  \nCTDI is a large scale logistics repair and e...
# 43  \nDescription:\n BayCare is currently in searc...
# 44  \n\n\n\n\n\n\n\n\n        Description \n      ...

# %%
import sys

#!{sys.executable} -m pip install lxml
from lxml import etree
#!{sys.executable} -m pip install beautifulsoup4
import requests
from bs4 import BeautifulSoup

## EXTRACT Pos NAME

URL = "https://www.indeed.com/viewjob?jk=9fc7b107970872a0&q=quality+manager&l=Tampa,+FL&from=web&advn=5762298694980534&adid=109133283&ad=-6NYlbfkN0BEDyJBSx9oqefqCav6hOw-T5ckpQBd37exZt4GFrGfjPPKHQItgk4TGXp5PwKHXTwlbcZwGXeZHj8LADRwasG0pVl15vyGG_kS7aY2_WivoD59RhuzolgQmCnIyP5UvcrRsuIFoincq2BAY-GJEu4z-r1LxLxgoPEc0lrrA2T90oIKunzrqJc4IYOf2_V2iBA81T9zCd1Hp0Z9Volj18pDUC4WbLnrCcL8ORpyrqSAe0uR4PxYikjInPRr8ozEqQoPC_Xs1Z-9cfTaexSAcoGVTTNIeiueptVJRb-BiL-2ess6nbHfw6ZZN9L7H7ILOermBSq0tm0Vi8ExiMdHfgVPbBL4hqvmyoU5rFx48nDCk1sqH5pAKYmb8gvTLabEx6Y%3D&pub=4a1b367933fd867b19b072952f68dceb&vjs=3"
soup = BeautifulSoup(page.content, "html.parser")
## Method 1
a=soup.find_all('h1')[0].get_text()

# Method 2
b=soup.select("div div h1")[0].get_text()

#Method 3
c=soup.find_all(class_="icl-u-xs-mb--xs icl-u-xs-mt--none jobsearch-JobInfoHeader-title")[0].get_text()

#Method 4

print(a,c)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_61/1063644974.py in <module>
#      15
#      16 # Method 2
# ---> 17 b=soup.select("div div h1")[0].get_text()
#      18
#      19 #Method 3
#
# IndexError: list index out of range

# %%
import sys

#!{sys.executable} -m pip install lxml
from lxml import etree
#!{sys.executable} -m pip install beautifulsoup4
import requests
from bs4 import BeautifulSoup

URL ="https://www.indeed.com/viewjob?cmp=Environmental-Engineering-Consultants,-Inc.&t=Civil+Environmental+Engineer&jk=d80925db679a0720&vjs=3"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")

#a=(soup.select("div nav div"))
#a=soup.find_all('p')
#for i in a:
   # #print('step')
   # print(i.get_text())
a=soup.find(class_="jobsearch-InlineCompanyRating icl-u-xs-mt--xs jobsearch-DesktopStickyContainer-companyrating").findSiblings
print(a)

#a=soup.select('div div div span')
#a=soup.find_all(class_="icl-u-xs-mr--xs")[0].get_text()
#print(a)
# Out:
# None
